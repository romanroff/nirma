# %%
from src.trace_log import (
    get_latest_trace_log_path,
    list_trace_log_paths,
    read_trace_events,
)

paths = list_trace_log_paths()
for path in paths:
    print(path)

latest = get_latest_trace_log_path()
print("latest:", latest)

events = read_trace_events(path=latest, limit=100)
events
